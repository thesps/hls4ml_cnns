# %%
import sys
from joblib import Parallel, delayed
import hls4ml
import tensorflow as tf
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_wrapper
from tensorflow_model_optimization.sparsity.keras import strip_pruning
from qkeras import QConv2D, QDense, Clip, QActivation
import onnx
import tensorflow_datasets as tfds
from hls4ml.model.profiling import numerical
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pandas
from hls4ml_scans import getNumpyData
from sklearn.metrics import roc_curve, auc, accuracy_score

# %%
def print_dict(d, indent=0):
    align=20
    for key, value in d.items():
        print('  ' * indent + str(key), end='')
        if isinstance(value, dict):
            print()
            print_dict(value, indent+1)
        else:
            print(':' + ' ' * (20 - len(key) - 2 * indent) + str(value))

# %%
(x_train, y_train), (x_test, y_test) = getNumpyData('svhn_cropped',oneHot=False)
# Out:
# 73257 train samples
# 26032 test samples

# %%
model_name = "full_final.h5"
model = tf.keras.models.load_model("models/"+model_name,custom_objects={'PruneLowMagnitude': pruning_wrapper.PruneLowMagnitude,'QDense': QDense, 'QConv2D': QConv2D, 'Clip': Clip, 'QActivation': QActivation})
model.summary()
model  = strip_pruning(model)
#(x_train, y_train), (x_test, y_test) = getNumpyData('svhn_cropped',oneHot=False)
a = hls4ml.model.profiling.activations_keras(model, x_test[:1000], fmt='summary')
intbits_a = int(np.ceil(max(np.log2(np.array(list(map(lambda x : x['whishi'], a)))))) + 1)
w = hls4ml.model.profiling.weights_keras(model, fmt='summary')
intbits_w = int(np.ceil(max(np.log2(np.array(list(map(lambda x : x['whishi'], w)))))) + 1)
print("Starting hls project, using {} int bits for weights+bias and {} int bits for outputs".format(intbits_a,intbits_w))
precision = 16
# Out:
# Model: "full_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 3)         12
# _________________________________________________________________
# conv_0 (Conv2D)              (None, 30, 30, 16)        432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 16)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 16)        64
# _________________________________________________________________
# conv_act_0 (Activation)      (None, 15, 15, 16)        0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 13, 13, 16)        2304
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 16)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 6, 16)          64
# _________________________________________________________________
# conv_act_1 (Activation)      (None, 6, 6, 16)          0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 4, 4, 24)          3456
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 24)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 2, 24)          96
# _________________________________________________________________
# conv_act_2 (Activation)      (None, 2, 2, 24)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense_0 (Dense)              (None, 42)                4032
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 42)                168
# _________________________________________________________________
# dense_act_0 (Activation)     (None, 42)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2688
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_act_1 (Activation)     (None, 64)                0
# _________________________________________________________________
# output_dense (Dense)         (None, 10)                650
# _________________________________________________________________
# output_softmax (Activation)  (None, 10)                0
# =================================================================
# Total params: 14,222
# Trainable params: 13,892
# Non-trainable params: 330
# _________________________________________________________________
#    input_1
#    batch_normalization
#    conv_0
#    max_pooling2d
#    batch_normalization_1
#    conv_act_0
#    conv_1
#    max_pooling2d_1
#    batch_normalization_2
#    conv_act_1
#    conv_2
#    max_pooling2d_2
#    batch_normalization_3
#    conv_act_2
#    flatten
#    dense_0
#    batch_normalization_4
#    dense_act_0
#    dense_1
#    batch_normalization_5
#    dense_act_1
#    output_dense
#    output_softmax
# Starting hls project, using 7 int bits for weights+bias and 5 int bits for outputs

# %%
#get model precision
pw = 'ap_fixed<{},{}>'.format(precision,intbits_w)
po = 'ap_fixed<{},{}>'.format(precision,intbits_a) 
if precision < 10:
    pw = 'ap_fixed<{},{}>'.format(precision,4)
    po = 'ap_fixed<{},{}>'.format(precision,4)  

# hls config
hls_cfg = {'Model' : {'Precision' : pw}}
hls_cfg['LayerName'] = {'output_softmax' : {'Strategy' : 'Stable'}}
hls_cfg['LayerType'] = {'Input' : {'Precision' : 'ap_fixed<16,6>', 'Trace':True},
                      'Dense' : {'Precision' : {'result' : po}, 'Trace':True},
                      'Conv2D' : {'Precision' : {'result' : po}, 'Trace':True},
                      'Pooling2D' : {'Precision' : po, 'Trace':True},
                      'BatchNormalization' : {'Precision' : po, 'Trace':True},
                      'Activation' : {'Precision' : {'result' : po}, 'Trace':True}
                     }
hls_cfg['Model']['PackFactor']  = 1
hls_cfg['Model']['ReuseFactor'] = 1

# vivado config
cfg = hls4ml.converters.create_vivado_config()
cfg['IOType']     = 'io_stream'
cfg['HLSConfig']  = hls_cfg
cfg['KerasModel'] = model
cfg['OutputDir']  = model_name.replace(".h5","")+"_bw%i"%(precision) # wherever you want the project to go
cfg['XilinxPart'] = 'xcvu9p-flgb2104-2l-e'
print_dict(hls_cfg)

#hls model
hls_model = hls4ml.converters.keras_to_hls(cfg)
hls4ml_pred, hls4ml_trace = hls_model.trace(x_test[:100])
keras_trace = hls4ml.model.profiling.get_ymodel_keras(model, x_test[:100])
y_hls = hls_model.predict(x_test[:1000])

for layer in hls_cfg['LayerName'].keys():
    print("Keras layer {}, first sample:".format(layer))
    print(keras_trace[layer][0])
    print("hls4ml layer {}, first sample:".format(layer))
    print(hls4ml_trace[layer][0])
# Out:
# Model
#   Precision:         ap_fixed<16,5>
#   PackFactor:        1
#   ReuseFactor:       1
# LayerName
#   output_softmax
#     Strategy:        Stable
# LayerType
#   Input
#     Precision:       ap_fixed<16,6>
#     Trace:           True
#   Dense
#     Precision
#       result:        ap_fixed<16,7>
#     Trace:           True
#   Conv2D
#     Precision
#       result:        ap_fixed<16,7>
#     Trace:           True
#   Pooling2D
#     Precision:       ap_fixed<16,7>
#     Trace:           True
#   BatchNormalization
#     Precision:       ap_fixed<16,7>
#     Trace:           True
#   Activation
#     Precision
#       result:        ap_fixed<16,7>
#     Trace:           True
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, current shape: [[None, 32, 32, 3]]
# Layer name: batch_normalization, layer type: BatchNormalization, current shape: [[None, 32, 32, 3]]
# Layer name: conv_0, layer type: Conv2D, current shape: [[None, 32, 32, 3]]
# Layer name: max_pooling2d, layer type: MaxPooling2D, current shape: [[None, 30, 30, 16]]
# Layer name: batch_normalization_1, layer type: BatchNormalization, current shape: [[None, 15, 15, 16]]
# Layer name: conv_act_0, layer type: Activation, current shape: [[None, 15, 15, 16]]
# Layer name: conv_1, layer type: Conv2D, current shape: [[None, 15, 15, 16]]
# Layer name: max_pooling2d_1, layer type: MaxPooling2D, current shape: [[None, 13, 13, 16]]
# Layer name: batch_normalization_2, layer type: BatchNormalization, current shape: [[None, 6, 6, 16]]
# Layer name: conv_act_1, layer type: Activation, current shape: [[None, 6, 6, 16]]
# Layer name: conv_2, layer type: Conv2D, current shape: [[None, 6, 6, 16]]
# Layer name: max_pooling2d_2, layer type: MaxPooling2D, current shape: [[None, 4, 4, 24]]
# Layer name: batch_normalization_3, layer type: BatchNormalization, current shape: [[None, 2, 2, 24]]
# Layer name: conv_act_2, layer type: Activation, current shape: [[None, 2, 2, 24]]
# Layer name: dense_0, layer type: Dense, current shape: [[None, 96]]
# Layer name: batch_normalization_4, layer type: BatchNormalization, current shape: [[None, 42]]
# Layer name: dense_act_0, layer type: Activation, current shape: [[None, 42]]
# Layer name: dense_1, layer type: Dense, current shape: [[None, 42]]
# Layer name: batch_normalization_5, layer type: BatchNormalization, current shape: [[None, 64]]
# Layer name: dense_act_1, layer type: Activation, current shape: [[None, 64]]
# Layer name: output_dense, layer type: Dense, current shape: [[None, 64]]
# Layer name: output_softmax, layer type: Softmax, current shape: [[None, 10]]
# Creating HLS model
# Recompiling myproject with tracing
# Writing HLS project
# Done
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-ac7e7f3900ce> in <module>
#      30 #hls model
#      31 hls_model = hls4ml.converters.keras_to_hls(cfg)
# ---> 32 hls4ml_pred, hls4ml_trace = hls_model.trace(x_test[:100])
#      33 keras_trace = hls4ml.model.profiling.get_ymodel_keras(model, x_test[:100])
#      34 y_hls = hls_model.predict(x_test[:1000])
#
# ~/miniconda3/envs/hls4ml-cnns/lib/python3.6/site-packages/hls4ml/model/hls_model.py in trace(self, x)
#     448         print('Recompiling {} with tracing'.format(self.config.get_project_name()))
#     449         self.config.trace_output = True
# --> 450         self.compile()
#     451
#     452         top_function, ctype = self._get_top_function(x)
#
# ~/miniconda3/envs/hls4ml-cnns/lib/python3.6/site-packages/hls4ml/model/hls_model.py in compile(self)
#     379                 dlclose_func.restype = ctypes.c_int
#     380                 dlclose_func(self._top_function_lib._handle)
# --> 381             self._top_function_lib = ctypes.cdll.LoadLibrary(lib_name)
#     382         finally:
#     383             os.chdir(curr_dir)
#
# ~/miniconda3/envs/hls4ml-cnns/lib/python3.6/ctypes/__init__.py in LoadLibrary(self, name)
#     424
#     425     def LoadLibrary(self, name):
# --> 426         return self._dlltype(name)
#     427
#     428 cdll = LibraryLoader(CDLL)
#
# ~/miniconda3/envs/hls4ml-cnns/lib/python3.6/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     346
#     347         if handle is None:
# --> 348             self._handle = _dlopen(self._name, mode)
#     349         else:
#     350             self._handle = handle
#
# OSError: dlopen(firmware/myproject.so, 6): image not found

# %%
print('Compile and predict')
x_test = x_test[:100]
y_test = y_test[:100]
y_predict        = model    .predict(x_test)
y_predict_hls4ml = hls_model.predict(x_test)
print("y_predict = ", y_predict[2])
print("y_predict_hls4ml = ", y_predict_hls4ml[2])
print("y_test = ", y_test[2])
print("arg ypred = ", np.argmax(y_predict[2]))
print("arg ypredhls = ", np.argmax(y_predict_hls4ml[2]))
data['accuracy_keras'] = accuracy_score (y_test, np.argmax(y_predict,axis=1))
data['accuracy_hls4ml'] = accuracy_score(y_test, np.argmax(y_predict_hls4ml,axis=1))

print("Accuracy: Keras={} hls4ml={}".format(data['accuracy_keras'],data['accuracy_hls4ml']))
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file='plot_model_{}.png'.format(precision))

hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file='plot_model_{}.png'.format(precision))
wp,ap = numerical(keras_model=model, hls_model=hls_model, X=x_test[:1000])

wp.savefig('%s_profile_weights_LayerTypePrecision.pdf'%cfg['OutputDir'])
ap.savefig('%s_profile_activations_LayerTypePrecision.pdf'%cfg['OutputDir'])
#hls_model.build(csim=False, synth=True, vsynth=True)

# %%
# Out:
# '{"class_name": "Functional", "config": {"name": "full_0", "layers": [{"class_name": "InputLayer", "config": {"batch_input_shape": [null, 32, 32, 3], "dtype": "float32", "sparse": false, "ragged": false, "name": "input_1"}, "name": "input_1", "inbound_nodes": []}, {"class_name": "BatchNormalization", "config": {"name": "batch_normalization", "trainable": true, "dtype": "float32", "axis": [3], "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_initializer": {"class_name": "Ones", "config": {}}, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "beta_regularizer": null, "gamma_regularizer": null, "beta_constraint": null, "gamma_constraint": null}, "name": "batch_normalization", "inbound_nodes": [[["input_1", 0, 0, {}]]]}, {"class_name": "Conv2D", "config": {"name": "conv_0", "trainable": true, "dtype": "float32", "filters": 16, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "linear", "use_bias": false, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_in", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "name": "conv_0", "inbound_nodes": [[["batch_normalization", 0, 0, {}]]]}, {"class_name": "MaxPooling2D", "config": {"name": "max_pooling2d", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}, "name": "max_pooling2d", "inbound_nodes": [[["conv_0", 0, 0, {}]]]}, {"class_name": "BatchNormalization", "config": {"name": "batch_normalization_1", "trainable": true, "dtype": "float32", "axis": [3], "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_initializer": {"class_name": "Ones", "config": {}}, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "beta_regularizer": null, "gamma_regularizer": null, "beta_constraint": null, "gamma_constraint": null}, "name": "batch_normalization_1", "inbound_nodes": [[["max_pooling2d", 0, 0, {}]]]}, {"class_name": "Activation", "config": {"name": "conv_act_0", "trainable": true, "dtype": "float32", "activation": "relu"}, "name": "conv_act_0", "inbound_nodes": [[["batch_normalization_1", 0, 0, {}]]]}, {"class_name": "Conv2D", "config": {"name": "conv_1", "trainable": true, "dtype": "float32", "filters": 16, "kernel_size": [3, 3], "strides": [1, 1], "padding": "valid", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "linear", "use_bias": false, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 1.0, "mode": "fan_in", "distribution": "uniform", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "name": "conv_1", "inbound_nodes": [[["conv_act_0", 0, 0, {}]]]}, {"class_name": "MaxPooling2D", "config": {"name": "max_pooling2d_1", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}, "name": "max_pooling2d_1", "inbound_nodes": [[["conv_1", 0, 0, {}]]]}, {"class_name": "BatchNormalization", "config": {"name": "batch_normalization_2", "trainable": true, "dtype": "float32", "axis": [3], "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_initializer": {"class_name": "Ones", "config": {}}, "moving_mean_in ...
